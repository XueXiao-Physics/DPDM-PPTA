# %%
from numpy import array
import numpy as np
import matplotlib.pyplot as plt
filt=1873030

# %% [markdown]
# # U1B

# %%
L=np.loadtxt('raw/raw_U1B')

lims=L[0:10]
mlhs=L[10:20]

lims[np.where(mlhs>filt)]=np.nan

# %%
fig,(ax1,ax2,ax3)=plt.subplots(3,1,figsize=(12,15))


mean=np.nanmean(lims,axis=0)
err=np.nanstd(lims,axis=0)/np.sqrt(10)
x=np.arange(0,125)/125*2.5-23.5+0.01
ax1.plot(x,lims.transpose(),'.');ax3.plot(x,mlhs.transpose(),'.');


nans=np.where(np.isnan(mean)==True)

mean=np.delete(mean,nans)
x=np.delete(x,nans)
err=np.delete(err,nans)


ax1.plot(x,mean,linewidth=4)
ax2.errorbar(x,mean,yerr=err,capsize=1.5,linewidth=2)



ax1.grid()
ax2.grid()
ax3.grid()

np.savetxt('U1B',(x,mean))
# Out:
# /home/xuex/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: Mean of empty slice
#   after removing the cwd from sys.path.

# %% [markdown]
# ### U1B_corr

# %%
L=np.loadtxt('raw/raw_U1B_corr')

lims=L[0:10]
mlhs=L[10:20]

lims[np.where(mlhs>filt)]=np.nan

# %%
fig,(ax1,ax2,ax3)=plt.subplots(3,1,figsize=(12,15))


mean=np.nanmean(lims,axis=0)
err=np.nanstd(lims,axis=0)/np.sqrt(10)
x=np.arange(0,125)/125*2.5-23.5+0.01
x=x[:84]
ax1.plot(x,lims.transpose(),'.');ax3.plot(x,mlhs.transpose(),'.');


nans=np.where(np.isnan(mean)==True)

mean=np.delete(mean,nans)
x=np.delete(x,nans)
err=np.delete(err,nans)


ax1.plot(x,mean,linewidth=4)
ax2.errorbar(x,mean,yerr=err,capsize=1.5,linewidth=2)



ax1.grid()
ax2.grid()
ax3.grid()

np.savetxt('U1B_corr',(x,mean))

# %% [markdown]
# # U1B-L

# %%
L=np.loadtxt('raw/raw_U1BL')

lims=L[0:10]
mlhs=L[10:20]

lims[np.where(mlhs>filt)]=np.nan

# %%
fig,(ax1,ax2,ax3)=plt.subplots(3,1,figsize=(12,15))


mean=np.nanmean(lims,axis=0)
err=np.nanstd(lims,axis=0)/np.sqrt(10)
x=np.arange(0,125)/125*2.5-23.5+0.01
ax1.plot(x,lims.transpose(),'.');ax3.plot(x,mlhs.transpose(),'.');


nans=np.where(np.isnan(mean)==True)

mean=np.delete(mean,nans)
x=np.delete(x,nans)
err=np.delete(err,nans)


ax1.plot(x,mean,linewidth=4)
ax2.errorbar(x,mean,yerr=err,capsize=1.5,linewidth=2)



ax1.grid()
ax2.grid()
ax3.grid()

np.savetxt('U1BL',(x,mean))
# Out:
# /home/xuex/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:4: RuntimeWarning: Mean of empty slice
#   after removing the cwd from sys.path.

# %% [markdown]
# # U1BL_corr

# %%
l1c=array([-25.12415086, -24.77914588, -24.58881799, -24.50940985,
       -25.05698651, -25.05042846, -24.55534315, -24.8670497 ,
       -24.41106158, -24.88636595, -24.92340749, -24.54376549,
       -24.79206534, -24.73357493, -25.16125489, -24.75709939,
       -24.93474895, -24.9121971 , -25.32118431, -24.77394893,
       -25.09181108, -25.13919408, -24.80674501, -24.82528068,
       -25.23912876, -24.84298426, -25.2450176 , -24.98663934,
       -25.41833906, -24.76072287, -25.13890921, -25.14316783,
       -25.33886619, -25.06209061, -24.82608806, -24.98613306,
       -25.23546125, -25.19712812, -25.00368975, -25.19572468,
       -24.3178859 , -24.09983887, -24.02538998, -23.45988453,
       -21.68356096, -21.62011171, -23.35025417, -23.67822408])


mlhs5c=array([1872932.379145, 1872930.478056, 1872932.39243 , 1872928.195307,
       1872934.801475, 1872930.067249, 1872931.150056, 1872928.094591,
       1872931.066406, 1872928.829285, 1872931.31887 , 1872927.722917,
       1872933.441938, 1872927.429179, 1872924.570731, 1872929.761272,
       1872930.902077, 1872929.412719, 1872933.110147, 1872932.042206,
       1872927.765304, 1872930.475425, 1872932.188414, 1872931.000851,
       1872925.319088, 1872928.328422, 1872931.041563, 1872926.329318,
       1872928.723609, 1872926.983334, 1872929.083411, 1872927.479095,
       1872925.137358, 1872925.688519, 1872924.985467, 1872926.379774,
       1872924.275987, 1872925.371063, 1872926.480706, 1872926.324309,
       1872930.53326 , 1872925.927191, 1872927.873437, 1872925.586801,
       1872927.407966, 1872925.992194, 1872924.69246 , 1872924.792144,
       1872924.779197, 1872926.634315, 1872925.740624, 1872924.905229,
       1872925.776441, 1872925.610472, 1872926.445096, 1872925.303319,
       1872925.322461, 1872925.683483, 1872927.676176, 1872926.37109 ,
       1872924.908226, 1872925.813159, 1872925.102247, 1872924.258703,
       1872925.317919, 1872925.794714, 1872923.99841 , 1872926.686017,
       1872927.511721, 1872926.230083, 1872924.074268, 1872926.086588,
       1872926.086284, 1872923.95523 , 1872928.05049 , 1872925.871626,
       1872924.899514, 1872926.09808 , 1872926.803151, 1872929.148242,
       1872964.089946, 1872965.345635, 1872947.486411, 1872959.960794])

# %%
fig,(ax1,ax2,ax3)=plt.subplots(3,1,figsize=(12,15))

l1c[np.where(mlhs1c>filt)]=np.nan
l2c[np.where(mlhs2c>filt)]=np.nan
l3c[np.where(mlhs3c>filt)]=np.nan
l4c[np.where(mlhs4c>filt)]=np.nan
l5c[np.where(mlhs5c>filt)]=np.nan


meanc=np.nanmean((l1c,l2c,l3c,l4c,l5c),axis=0)
errc=np.nanstd((l1c,l2c,l3c,l4c,l5c),axis=0)
xc=np.arange(0,125)/125*2.5-23.5+0.01
xc=xc[:84]

ax1.plot(xc,l1c,'.');ax3.plot(mlhs1c,'.');
ax1.plot(xc,l2c,'.');ax3.plot(mlhs2c,'.');
ax1.plot(xc,l3c,'.');ax3.plot(mlhs3c,'.');
ax1.plot(xc,l4c,'.');ax3.plot(mlhs4c,'.');
ax1.plot(xc,l5c,'.');ax3.plot(mlhs5c,'.');


nansc=np.where(np.isnan(mean)==True)
meanc=np.delete(meanc,nansc)
xc=np.delete(xc,nansc)
errc=np.delete(errc,nansc)


ax1.plot(xc,meanc,linewidth=4)
ax2.errorbar(xc,meanc,yerr=errc,capsize=1.5,linewidth=2)



ax1.grid()
ax2.grid()
ax3.grid()

np.savetxt('U1BL_corr',(xc,meanc))

# %%
plt.figure(figsize=(10,6))
plt.plot(x,mean)
plt.plot(xc[0:74],meanc[0:74])
